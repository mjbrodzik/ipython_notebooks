# %%
# %pylab notebook
import matplotlib.pyplot as plt
import numpy as np
from charistools.readers import ModisTileCube
pylab.rcParams['figure.figsize'] = (10.0, 8.0)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %cd /Users/brodzik/projects/CHARIS/grain_size/MODSCAG_GF/v10/h25v06
# %ls
# Out:
# /Users/brodzik/projects/CHARIS/grain_size/MODSCAG_GF/v10/h25v06
# MODSCAG_GF_GrainSize.v0.10.h25v06_2004.h5

# %%
cube.close()

# %%
cube = ModisTileCube('MODSCAG_GF_GrainSize.v0.10.h25v06_2004.h5', varname='grain_size')

# %%
d5 = cube.read(doy=32)

# %%
d5.shape
# Out:
# (2400, 2400)

# %%
np.amin(d5), np.amax(d5)
# Out:
# (0, 1080)

# %%
cube.d
# Out:
# <type 'netCDF4._netCDF4.Variable'>
# uint16 grain_size(phony_dim_0, phony_dim_1, phony_dim_1)
#     _FillValue: 65535
# path = /500m
# unlimited dimensions:
# current shape = (366, 2400, 2400)
# filling off

# %%
cube_v9.close()

# %%
# %cd /Users/brodzik/projects/CHARIS/grain_size/MODSCAG_GF/v09/h25v06
# %ls
# Out:
# /Users/brodzik/projects/CHARIS/grain_size/MODSCAG_GF/v09/h25v06
# MODSCAG_GF_GrainSize.v0.9.h25v06_2001.h5
# MODSCAG_GF_GrainSize.v0.9.h25v06_2002.h5
# MODSCAG_GF_GrainSize.v0.9.h25v06_2003.h5
# MODSCAG_GF_GrainSize.v0.9.h25v06_2004.h5
# MODSCAG_GF_GrainSize.v0.9.h25v06_2005.h5
# MODSCAG_GF_GrainSize.v0.9.h25v06_2006.h5
# MODSCAG_GF_GrainSize.v0.9.h25v06_2007.h5
# MODSCAG_GF_GrainSize.v0.9.h25v06_2008.h5
# MODSCAG_GF_GrainSize.v0.9.h25v06_2009.h5
# MODSCAG_GF_GrainSize.v0.9.h25v06_2010.h5
# MODSCAG_GF_GrainSize.v0.9.h25v06_2011.h5
# MODSCAG_GF_GrainSize.v0.9.h25v06_2012.h5
# MODSCAG_GF_GrainSize.v0.9.h25v06_2013.h5
# MODSCAG_GF_GrainSize.v0.9.h25v06_2014.h5

# %%
cube_v9 = ModisTileCube('MODSCAG_GF_GrainSize.v0.9.h25v06_2004.h5', varname='grain_size')

# %%
orig_d5 = cube_v9.read(doy=32)
orig_d5.shape
# Out:
# (2400, 2400)

# %%
np.amin(orig_d5), np.amax(orig_d5)
# Out:
# (0, 1080)

# %%
cube_v9.d
# Out:
# <type 'netCDF4._netCDF4.Variable'>
# uint16 grain_size(phony_dim_0, phony_dim_1, phony_dim_1)
#     _FillValue: 65535
# path = /500m
# unlimited dimensions:
# current shape = (366, 2400, 2400)
# filling off

# %%
fig, ax = plt.subplots(1,2)
ax[0].imshow(orig_d5, cmap=plt.cm.gray, vmin=0, vmax=200, interpolation='None')
ax[0].set_title("Orig (v09)")
ax[1].imshow(d5, cmap=plt.cm.gray, vmin=0, vmax=200, interpolation='None')
ax[1].set_title("New (v10)")
plt.axis('off')
#fig.savefig('/Users/brodzik/tmp/SRTMGL3_vs_CHARIS_DEMv2.png')
# Out:
# <img src="data:image/png;base64,...">
# (-0.5, 2399.5, 2399.5, -0.5)

# %%
d5.dtype, orig_d5.dtype

# %%
diff = d5 - orig_d5
print(np.amin(diff), np.amax(diff))

# %%
fig, ax = plt.subplots(1)
ax.imshow(diff, cmap=plt.cm.gray, interpolation='None')
ax.set_title("Diff (new - orig)")
plt.axis('off')

# %%
print(d5[2397:2399, 2397:2399])

# %%
print(orig_d5[2397:2399, 2397:2399])
