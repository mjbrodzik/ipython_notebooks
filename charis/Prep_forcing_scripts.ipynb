# %%
# %pylab notebook
from charistools.readers import read_tile
import glob
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import re
pd.options.display.max_rows = 200
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
basin_name = "IN"
basin = "%s_snow_subs_basins_modis_masks" % basin_name
# %cd /Users/brodzik/projects/CHARIS/basins/subbasins_of_major_basins/
# %cd $basin
# Out:
# /Users/brodzik/projects/CHARIS/basins/subbasins_of_major_basins
# /Users/brodzik/projects/CHARIS/basins/subbasins_of_major_basins/IN_snow_subs_basins_modis_masks

# %%
# process multiple-tile basins before single-tile basins, so they start first
list = glob.glob("??_[1-4]tile_basins_with_h23-4.txt")
list = sorted(list, reverse=True)
list
# Out:
# ['IN_2tile_basins_with_h23-4.txt', 'IN_1tile_basins_with_h23-4.txt']

# %%
start_year = 2001
stop_year = 2014
years = np.arange(stop_year - start_year + 1) + start_year
years
# Out:
# array([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014])

# %%
nstrikes = 1

# %%
out_fh = open("%s_run_forcings_with_h23-4.sh" % (basin_name), "w")
count = 0
for file in list:
    with open(file, "r") as f:
        subbasins = f.readlines()
        for subbasin in subbasins:
            print("Next: %s" % subbasin)
            for year in years:
                out_fh.write("/projects/brodzik/charis_ti_melt/run_forcings.py --year=%d --nstrikes=%d %s" % (
                    year, nstrikes, subbasin))
                count = count + 1
out_fh.close()
# Out:
# Next: IN_OBJECTID12
#
# Next: IN_OBJECTID32
#
# Next: IN_OBJECTID4
#
# Next: IN_OBJECTID47
#
# Next: IN_OBJECTID6
#
# Next: IN_OBJECTID10
#
# Next: IN_OBJECTID11
#
# Next: IN_OBJECTID13
#
# Next: IN_OBJECTID14
#
# Next: IN_OBJECTID17
#
# Next: IN_OBJECTID18
#
# Next: IN_OBJECTID19
#
# Next: IN_OBJECTID2
#
# Next: IN_OBJECTID20
#
# Next: IN_OBJECTID21
#
# Next: IN_OBJECTID22
#
# Next: IN_OBJECTID23
#
# Next: IN_OBJECTID24
#
# Next: IN_OBJECTID25
#
# Next: IN_OBJECTID26
#
# Next: IN_OBJECTID27
#
# Next: IN_OBJECTID28
#
# Next: IN_OBJECTID29
#
# Next: IN_OBJECTID30
#
# Next: IN_OBJECTID31
#
# Next: IN_OBJECTID33
#
# Next: IN_OBJECTID34
#
# Next: IN_OBJECTID36
#
# Next: IN_OBJECTID37
#
# Next: IN_OBJECTID39
#
# Next: IN_OBJECTID44
#
# Next: IN_OBJECTID48
#
# Next: IN_OBJECTID53
#
# Next: IN_OBJECTID56
#
# Next: IN_OBJECTID57
#
# Next: IN_OBJECTID58
#
# Next: IN_OBJECTID59
#
# Next: IN_OBJECTID62
#
# Next: IN_OBJECTID63
#
# Next: IN_OBJECTID7
#
# Next: IN_OBJECTID73
#
# Next: IN_OBJECTID8
#
# Next: IN_OBJECTID9

# %%
# %cat IN_run_forcings_with_h23-4.sh
# Out:
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID12
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID12
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID12
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID12
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID12
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID12
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID12
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID12
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID12
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID12
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID12
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID12
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID12
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID12
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID32
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID32
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID32
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID32
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID32
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID32
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID32
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID32
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID32
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID32
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID32
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID32
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID32
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID32
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID4
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID4
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID4
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID4
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID4
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID4
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID4
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID4
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID4
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID4
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID4
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID4
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID4
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID4
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID47
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID47
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID47
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID47
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID47
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID47
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID47
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID47
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID47
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID47
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID47
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID47
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID47
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID47
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID6
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID6
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID6
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID6
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID6
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID6
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID6
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID6
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID6
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID6
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID6
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID6
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID6
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID6
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID10
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID10
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID10
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID10
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID10
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID10
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID10
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID10
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID10
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID10
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID10
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID10
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID10
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID10
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID11
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID11
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID11
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID11
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID11
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID11
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID11
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID11
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID11
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID11
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID11
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID11
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID11
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID11
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID13
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID13
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID13
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID13
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID13
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID13
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID13
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID13
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID13
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID13
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID13
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID13
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID13
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID13
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID14
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID14
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID14
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID14
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID14
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID14
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID14
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID14
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID14
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID14
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID14
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID14
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID14
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID14
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID17
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID17
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID17
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID17
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID17
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID17
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID17
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID17
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID17
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID17
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID17
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID17
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID17
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID17
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID18
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID18
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID18
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID18
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID18
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID18
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID18
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID18
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID18
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID18
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID18
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID18
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID18
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID18
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID19
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID19
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID19
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID19
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID19
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID19
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID19
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID19
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID19
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID19
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID19
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID19
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID19
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID19
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID2
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID2
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID2
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID2
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID2
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID2
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID2
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID2
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID2
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID2
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID2
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID2
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID2
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID2
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID20
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID20
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID20
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID20
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID20
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID20
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID20
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID20
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID20
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID20
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID20
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID20
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID20
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID20
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID21
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID21
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID21
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID21
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID21
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID21
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID21
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID21
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID21
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID21
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID21
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID21
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID21
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID21
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID22
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID22
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID22
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID22
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID22
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID22
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID22
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID22
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID22
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID22
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID22
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID22
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID22
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID22
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID23
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID23
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID23
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID23
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID23
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID23
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID23
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID23
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID23
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID23
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID23
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID23
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID23
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID23
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID24
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID24
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID24
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID24
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID24
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID24
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID24
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID24
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID24
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID24
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID24
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID24
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID24
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID24
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID25
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID25
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID25
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID25
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID25
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID25
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID25
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID25
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID25
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID25
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID25
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID25
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID25
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID25
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID26
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID26
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID26
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID26
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID26
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID26
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID26
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID26
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID26
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID26
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID26
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID26
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID26
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID26
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID27
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID27
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID27
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID27
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID27
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID27
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID27
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID27
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID27
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID27
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID27
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID27
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID27
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID27
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID28
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID28
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID28
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID28
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID28
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID28
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID28
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID28
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID28
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID28
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID28
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID28
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID28
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID28
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID29
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID29
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID29
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID29
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID29
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID29
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID29
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID29
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID29
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID29
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID29
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID29
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID29
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID29
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID30
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID30
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID30
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID30
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID30
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID30
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID30
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID30
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID30
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID30
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID30
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID30
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID30
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID30
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID31
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID31
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID31
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID31
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID31
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID31
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID31
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID31
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID31
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID31
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID31
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID31
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID31
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID31
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID33
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID33
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID33
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID33
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID33
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID33
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID33
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID33
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID33
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID33
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID33
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID33
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID33
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID33
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID34
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID34
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID34
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID34
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID34
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID34
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID34
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID34
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID34
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID34
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID34
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID34
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID34
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID34
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID36
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID36
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID36
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID36
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID36
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID36
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID36
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID36
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID36
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID36
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID36
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID36
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID36
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID36
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID37
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID37
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID37
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID37
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID37
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID37
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID37
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID37
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID37
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID37
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID37
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID37
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID37
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID37
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID39
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID39
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID39
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID39
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID39
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID39
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID39
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID39
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID39
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID39
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID39
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID39
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID39
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID39
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID44
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID44
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID44
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID44
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID44
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID44
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID44
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID44
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID44
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID44
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID44
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID44
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID44
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID44
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID48
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID48
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID48
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID48
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID48
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID48
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID48
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID48
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID48
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID48
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID48
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID48
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID48
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID48
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID53
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID53
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID53
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID53
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID53
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID53
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID53
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID53
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID53
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID53
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID53
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID53
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID53
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID53
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID56
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID56
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID56
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID56
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID56
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID56
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID56
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID56
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID56
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID56
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID56
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID56
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID56
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID56
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID57
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID57
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID57
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID57
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID57
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID57
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID57
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID57
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID57
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID57
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID57
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID57
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID57
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID57
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID58
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID58
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID58
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID58
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID58
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID58
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID58
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID58
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID58
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID58
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID58
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID58
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID58
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID58
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID59
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID59
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID59
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID59
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID59
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID59
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID59
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID59
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID59
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID59
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID59
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID59
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID59
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID59
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID62
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID62
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID62
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID62
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID62
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID62
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID62
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID62
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID62
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID62
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID62
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID62
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID62
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID62
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID63
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID63
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID63
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID63
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID63
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID63
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID63
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID63
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID63
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID63
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID63
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID63
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID63
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID63
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID7
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID7
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID7
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID7
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID7
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID7
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID7
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID7
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID7
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID7
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID7
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID7
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID7
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID7
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID73
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID73
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID73
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID73
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID73
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID73
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID73
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID73
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID73
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID73
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID73
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID73
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID73
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID73
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID8
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID8
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID8
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID8
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID8
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID8
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID8
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID8
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID8
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID8
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID8
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID8
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID8
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID8
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2001 --nstrikes=1 IN_OBJECTID9
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2002 --nstrikes=1 IN_OBJECTID9
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2003 --nstrikes=1 IN_OBJECTID9
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2004 --nstrikes=1 IN_OBJECTID9
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2005 --nstrikes=1 IN_OBJECTID9
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2006 --nstrikes=1 IN_OBJECTID9
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2007 --nstrikes=1 IN_OBJECTID9
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2008 --nstrikes=1 IN_OBJECTID9
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2009 --nstrikes=1 IN_OBJECTID9
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2010 --nstrikes=1 IN_OBJECTID9
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2011 --nstrikes=1 IN_OBJECTID9
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2012 --nstrikes=1 IN_OBJECTID9
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2013 --nstrikes=1 IN_OBJECTID9
# /projects/brodzik/charis_ti_melt/run_forcings.py --year=2014 --nstrikes=1 IN_OBJECTID9

# %%
print("count=%d, use %d nodes, assuming 12 tasks/node" % (count, (count+1)/12 + 1))
# Out:
# count=602, use 51 nodes, assuming 12 tasks/node

# %%
print 51*12
# Out:
# 612

# %%
72*12
# Out:
# 864
